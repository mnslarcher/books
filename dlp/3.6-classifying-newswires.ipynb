# %%
import keras
keras.__version__
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# '2.2.0'

# %%
from keras.datasets import reuters

(train_data, train_labels), (test_data, test_labels) = reuters.load_data(num_words=10000)

# %%
len(train_data)
# Out:
# 8982

# %%
len(test_data)
# Out:
# 2246

# %%
train_data[10]
# Out:
# [1,
#  245,
#  273,
#  207,
#  156,
#  53,
#  74,
#  160,
#  26,
#  14,
#  46,
#  296,
#  26,
#  39,
#  74,
#  2979,
#  3554,
#  14,
#  46,
#  4689,
#  4329,
#  86,
#  61,
#  3499,
#  4795,
#  14,
#  61,
#  451,
#  4329,
#  17,
#  12]

# %%
word_index = reuters.get_word_index()
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])
decoded_newswire = ' '.join([reverse_word_index.get(i - 3, '?') for i in train_data[0]])

# %%
decoded_newswire
# Out:
# '? ? ? said as a result of its december acquisition of space co it expects earnings per share in 1987 of 1 15 to 1 30 dlrs per share up from 70 cts in 1986 the company said pretax net should rise to nine to 10 mln dlrs from six mln dlrs in 1986 and rental operation revenues to 19 to 22 mln dlrs from 12 5 mln dlrs it said cash flow per share this year should be 2 50 to three dlrs reuter 3'

# %%
train_labels[10]
# Out:
# 3

# %%
import numpy as np

def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.
    return results

x_train = vectorize_sequences(train_data)
x_test = vectorize_sequences(test_data)

# %%
def to_one_hot(labels, dimension=46):
    results = np.zeros((len(labels), dimension))
    for i, label in enumerate(labels):
        results[i, label] = 1.
    return results

one_hot_train_labels = to_one_hot(train_labels)
one_hot_test_labels = to_one_hot(test_labels)

# %%
from keras.utils.np_utils import to_categorical

one_hot_train_labels = to_categorical(train_labels)
one_hot_test_labels = to_categorical(test_labels)

# %%
from keras import models
from keras import layers

model = models.Sequential()
model.add(layers.Dense(64, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(46, activation='softmax'))

# %%
model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
x_val = x_train[:1000]
partial_x_train = x_train[1000:]

y_val = one_hot_train_labels[:1000]
partial_y_train = one_hot_train_labels[1000:]

# %%
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs=20,
                    batch_size=512,
                    validation_data=(x_val, y_val))
# Out:
# Train on 7982 samples, validate on 1000 samples
# Epoch 1/20
# 7982/7982 [==============================] - 1s 172us/step - loss: 2.5322 - acc: 0.4955 - val_loss: 1.7208 - val_acc: 0.6120
# Epoch 2/20
# 7982/7982 [==============================] - 1s 82us/step - loss: 1.4452 - acc: 0.6879 - val_loss: 1.3459 - val_acc: 0.7060
# Epoch 3/20
# 7982/7982 [==============================] - 1s 81us/step - loss: 1.0953 - acc: 0.7651 - val_loss: 1.1708 - val_acc: 0.7430
# Epoch 4/20
# 7982/7982 [==============================] - 1s 82us/step - loss: 0.8697 - acc: 0.8165 - val_loss: 1.0793 - val_acc: 0.7590
# Epoch 5/20
# 7982/7982 [==============================] - 1s 81us/step - loss: 0.7034 - acc: 0.8472 - val_loss: 0.9844 - val_acc: 0.7810
# Epoch 6/20
# 7982/7982 [==============================] - 1s 82us/step - loss: 0.5667 - acc: 0.8802 - val_loss: 0.9411 - val_acc: 0.8040
# Epoch 7/20
# 7982/7982 [==============================] - 1s 81us/step - loss: 0.4581 - acc: 0.9048 - val_loss: 0.9083 - val_acc: 0.8020
# Epoch 8/20
# 7982/7982 [==============================] - 1s 81us/step - loss: 0.3695 - acc: 0.9231 - val_loss: 0.9363 - val_acc: 0.7890
# Epoch 9/20
# 7982/7982 [==============================] - 1s 82us/step - loss: 0.3032 - acc: 0.9315 - val_loss: 0.8917 - val_acc: 0.8090
# Epoch 10/20
# 7982/7982 [==============================] - 1s 81us/step - loss: 0.2537 - acc: 0.9414 - val_loss: 0.9071 - val_acc: 0.8110
# Epoch 11/20
# 7982/7982 [==============================] - 1s 81us/step - loss: 0.2187 - acc: 0.9471 - val_loss: 0.9177 - val_acc: 0.8130
# Epoch 12/20
# 7982/7982 [==============================] - 1s 81us/step - loss: 0.1873 - acc: 0.9508 - val_loss: 0.9027 - val_acc: 0.8130
# Epoch 13/20
# 7982/7982 [==============================] - 1s 81us/step - loss: 0.1703 - acc: 0.9521 - val_loss: 0.9323 - val_acc: 0.8110
# Epoch 14/20
# 7982/7982 [==============================] - 1s 82us/step - loss: 0.1536 - acc: 0.9554 - val_loss: 0.9689 - val_acc: 0.8050
# Epoch 15/20
# 7982/7982 [==============================] - 1s 82us/step - loss: 0.1390 - acc: 0.9560 - val_loss: 0.9686 - val_acc: 0.8150
# Epoch 16/20
# 7982/7982 [==============================] - 1s 82us/step - loss: 0.1313 - acc: 0.9560 - val_loss: 1.0220 - val_acc: 0.8060
# Epoch 17/20
# 7982/7982 [==============================] - 1s 81us/step - loss: 0.1217 - acc: 0.9579 - val_loss: 1.0254 - val_acc: 0.7970
# Epoch 18/20
# 7982/7982 [==============================] - 1s 81us/step - loss: 0.1198 - acc: 0.9582 - val_loss: 1.0430 - val_acc: 0.8060
# Epoch 19/20
# 7982/7982 [==============================] - 1s 83us/step - loss: 0.1138 - acc: 0.9597 - val_loss: 1.0955 - val_acc: 0.7970
# Epoch 20/20
# 7982/7982 [==============================] - 1s 83us/step - loss: 0.1111 - acc: 0.9593 - val_loss: 1.0674 - val_acc: 0.8020

# %%
import matplotlib.pyplot as plt

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Acc')
plt.legend()

plt.show()

# %%
model = models.Sequential()
model.add(layers.Dense(64, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(46, activation='softmax'))

model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.fit(partial_x_train,
          partial_y_train,
          epochs=8,
          batch_size=512,
          validation_data=(x_val, y_val))

results = model.evaluate(x_test, one_hot_test_labels)
# Out:
# Train on 7982 samples, validate on 1000 samples
# Epoch 1/8
# 7982/7982 [==============================] - 1s 115us/step - loss: 2.5398 - acc: 0.5226 - val_loss: 1.6733 - val_acc: 0.6570
# Epoch 2/8
# 7982/7982 [==============================] - 1s 83us/step - loss: 1.3712 - acc: 0.7121 - val_loss: 1.2758 - val_acc: 0.7210
# Epoch 3/8
# 7982/7982 [==============================] - 1s 83us/step - loss: 1.0136 - acc: 0.7781 - val_loss: 1.1303 - val_acc: 0.7530
# Epoch 4/8
# 7982/7982 [==============================] - 1s 83us/step - loss: 0.7976 - acc: 0.8251 - val_loss: 1.0539 - val_acc: 0.7590
# Epoch 5/8
# 7982/7982 [==============================] - 1s 83us/step - loss: 0.6393 - acc: 0.8624 - val_loss: 0.9754 - val_acc: 0.7920
# Epoch 6/8
# 7982/7982 [==============================] - 1s 83us/step - loss: 0.5124 - acc: 0.8921 - val_loss: 0.9102 - val_acc: 0.8140
# Epoch 7/8
# 7982/7982 [==============================] - 1s 83us/step - loss: 0.4124 - acc: 0.9139 - val_loss: 0.8932 - val_acc: 0.8210
# Epoch 8/8
# 7982/7982 [==============================] - 1s 83us/step - loss: 0.3355 - acc: 0.9290 - val_loss: 0.8733 - val_acc: 0.8260
# 2246/2246 [==============================] - 0s 67us/step

# %%
results
# Out:
# [0.9844293269533614, 0.7836153161175423]

# %%
import copy

test_labels_copy = copy.copy(test_labels)
np.random.shuffle(test_labels_copy)
float(np.sum(np.array(test_labels) == np.array(test_labels_copy))) / len(test_labels)
# Out:
# 0.19679430097951914

# %%
predictions = model.predict(x_test)

# %%
predictions[0].shape
# Out:
# (46,)

# %%
np.sum(predictions[0])
# Out:
# 1.0000001

# %%
np.argmax(predictions[0])
# Out:
# 3

# %%
y_train = np.array(train_labels)
y_test = np.array(test_labels)

# %%
model.compile(optimizer='rmsprop',
              loss='sparse_categorical_crossentropy',
              metrics=['acc'])

# %%
model = models.Sequential()
model.add(layers.Dense(64, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(4, activation='relu'))
model.add(layers.Dense(46, activation='softmax'))

model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.fit(partial_x_train,
          partial_y_train,
          epochs=20,
          batch_size=128,
          validation_data=(x_val, y_val))
# Out:
# Train on 7982 samples, validate on 1000 samples
# Epoch 1/20
# 7982/7982 [==============================] - 1s 122us/step - loss: 2.7073 - acc: 0.4411 - val_loss: 2.0155 - val_acc: 0.5930
# Epoch 2/20
# 7982/7982 [==============================] - 1s 85us/step - loss: 1.7341 - acc: 0.6183 - val_loss: 1.6573 - val_acc: 0.6100
# Epoch 3/20
# 7982/7982 [==============================] - 1s 84us/step - loss: 1.4678 - acc: 0.6359 - val_loss: 1.5688 - val_acc: 0.6080
# Epoch 4/20
# 7982/7982 [==============================] - 1s 81us/step - loss: 1.3273 - acc: 0.6446 - val_loss: 1.4833 - val_acc: 0.6170
# Epoch 5/20
# 7982/7982 [==============================] - 1s 78us/step - loss: 1.2168 - acc: 0.6498 - val_loss: 1.4540 - val_acc: 0.6250
# Epoch 6/20
# 7982/7982 [==============================] - 1s 84us/step - loss: 1.1265 - acc: 0.6753 - val_loss: 1.4326 - val_acc: 0.6350
# Epoch 7/20
# 7982/7982 [==============================] - 1s 83us/step - loss: 1.0522 - acc: 0.6944 - val_loss: 1.4520 - val_acc: 0.6420
# Epoch 8/20
# 7982/7982 [==============================] - 1s 84us/step - loss: 0.9927 - acc: 0.7037 - val_loss: 1.4426 - val_acc: 0.6510
# Epoch 9/20
# 7982/7982 [==============================] - 1s 84us/step - loss: 0.9425 - acc: 0.7167 - val_loss: 1.4766 - val_acc: 0.6500
# Epoch 10/20
# 7982/7982 [==============================] - 1s 84us/step - loss: 0.8978 - acc: 0.7429 - val_loss: 1.5227 - val_acc: 0.6480
# Epoch 11/20
# 7982/7982 [==============================] - 1s 84us/step - loss: 0.8602 - acc: 0.7547 - val_loss: 1.5150 - val_acc: 0.6670
# Epoch 12/20
# 7982/7982 [==============================] - 1s 84us/step - loss: 0.8261 - acc: 0.7602 - val_loss: 1.5255 - val_acc: 0.6690
# Epoch 13/20
# 7982/7982 [==============================] - 1s 85us/step - loss: 0.7962 - acc: 0.7677 - val_loss: 1.5737 - val_acc: 0.6660
# Epoch 14/20
# 7982/7982 [==============================] - 1s 84us/step - loss: 0.7717 - acc: 0.7734 - val_loss: 1.6052 - val_acc: 0.6640
# Epoch 15/20
# 7982/7982 [==============================] - 1s 85us/step - loss: 0.7449 - acc: 0.7814 - val_loss: 1.6424 - val_acc: 0.6690
# Epoch 16/20
# 7982/7982 [==============================] - 1s 84us/step - loss: 0.7237 - acc: 0.7886 - val_loss: 1.7200 - val_acc: 0.6650
# Epoch 17/20
# 7982/7982 [==============================] - 1s 83us/step - loss: 0.7052 - acc: 0.7964 - val_loss: 1.7392 - val_acc: 0.6640
# Epoch 18/20
# 7982/7982 [==============================] - 1s 83us/step - loss: 0.6849 - acc: 0.8022 - val_loss: 1.7847 - val_acc: 0.6670
# Epoch 19/20
# 7982/7982 [==============================] - 1s 84us/step - loss: 0.6680 - acc: 0.8086 - val_loss: 1.7986 - val_acc: 0.6700
# Epoch 20/20
# 7982/7982 [==============================] - 1s 84us/step - loss: 0.6532 - acc: 0.8158 - val_loss: 1.8293 - val_acc: 0.6680

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Acc')
plt.legend()

plt.show()

# %%
def plot_loss_and_acc(history):
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    acc = history.history['acc']
    val_acc = history.history['val_acc']
    epochs = np.arange(len(loss))

    fig = plt.figure()
    
    ax1 = fig.add_subplot(121)
    ax1.plot(epochs, loss, label='Training loss')
    ax1.plot(epochs, val_loss, label='Validation loss')
    ax1.grid(ls='--')
    ax1.legend()
    
    ax2 = fig.add_subplot(122)
    ax2.plot(epochs, acc, label='Training acc')
    ax2.plot(epochs, val_acc, label='Validation acc')
    ax2.grid(ls='--')
    ax2.legend()

    plt.show()


def further_experiments(hidden_layers=2, 
                        units=64):
    print('hidden_layers={}, units={}\n'.format(hidden_layers, units))
    model = models.Sequential()
    model.add(layers.Dense(units, activation='relu', input_shape=(10000,)))
    for i in range(hidden_layers - 1):
        model.add(layers.Dense(units, activation='relu'))
    model.add(layers.Dense(46, activation='softmax'))
    
    model.compile(optimizer='rmsprop',
                  loss='categorical_crossentropy',
                 metrics=['accuracy'])
    history = model.fit(partial_x_train, 
                        partial_y_train, 
                        epochs=20, 
                        batch_size=512,
                        validation_data=(x_val, y_val), verbose=0)
    plot_loss_and_acc(history)
    print('Test accuracy: %.4f\n' % model.evaluate(x_test, one_hot_test_labels, verbose=0)[1])

# %%
further_experiments()
further_experiments(units=32)
further_experiments(units=128)
further_experiments(hidden_layers=1)
further_experiments(hidden_layers=2)
# Out:
# hidden_layers=2, units=64
# Test accuracy: 0.7796
#
# hidden_layers=2, units=32
# Test accuracy: 0.7707
#
# hidden_layers=2, units=128
# Test accuracy: 0.7796
#
# hidden_layers=1, units=64
# Test accuracy: 0.7876
#
# hidden_layers=2, units=64
# Test accuracy: 0.7898
